# %%
print("Hello! Python!")
# Out:
# Hello! Python!

# %%
class Person:
    def __init__(self,name):
        self.name = name #attribute

# %%
p1:Person = Person("robert")
print(p1.name)

p2:Person = Person(name="jenny")
print(p2.name)
# Out:
# robert
# jenny
