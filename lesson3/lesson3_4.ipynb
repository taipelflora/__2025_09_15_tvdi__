# %%
try:
    raise NameError("名字錯誤")
    print("Hello!")
except Exception as e:
    print(f"出現錯誤,錯誤是:{e}")
else:
    print("沒有錯誤")
# Out:
# 出現錯誤,錯誤是:名字錯誤

# %%
try:
    #raise NameError("名字錯誤")
    print("Hello!")
except NameError:
    print("名字錯誤")
except Exception as e:
    print(f"出現錯誤,錯誤是:{e}")
else:
    print("沒有錯誤")
# Out:
# Hello!
# 沒有錯誤
